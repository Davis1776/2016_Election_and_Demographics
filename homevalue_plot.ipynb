# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import requests
import seaborn as sns
import csv
import gmaps

# %%
# Read merged CSV file - election results and census data
csv_path = "merged_file.csv"
merged_df = pd.read_csv(csv_path)

merged_df.head(3)
# Out:
#    Unnamed: 0    State State Abbr              County  DEM Votes  GOP Votes  \
# 0           0  Indiana         IN        Adams County       2802       9642
# 1           1  Indiana         IN        Allen County      55222      83801
# 2           2  Indiana         IN  Bartholomew County       9841      20637
#
#    Total Votes     DEM %     GOP %  Total Population  ...  \
# 0        13039  0.214894  0.739474           34813.0  ...
# 1       145787  0.378785  0.574818          365565.0  ...
# 2        32389  0.303838  0.637161           80203.0  ...
#
#    Education (Bachelors)  Education (Masters)  Education (Professional)  \
# 0                 2311.0                768.0                     126.0
# 1                42160.0              16367.0                    4152.0
# 2                 9685.0               5255.0                     499.0
#
#    Education (Doctorate)  Median Income  Income Per Capita  Median Home Value  \
# 0                   64.0        47572.0            21173.0           114600.0
# 1                 1694.0        49574.0            26058.0           116400.0
# 2                  632.0        55874.0            28631.0           137500.0
#
#    Pop in Labor Force  Pop Not in Labor Force  Unemployed
# 0             15975.0                  8948.0       872.0
# 1            186706.0                 93216.0     13152.0
# 2             41710.0                 21169.0      2165.0
#
# [3 rows x 31 columns]

# %%
merged_df.columns
# Out:
# Index(['Unnamed: 0', 'State', 'State Abbr', 'County', 'DEM Votes', 'GOP Votes',
#        'Total Votes', 'DEM %', 'GOP %', 'Total Population',
#        'Population (White)', 'Population (African-American)',
#        'Population (Asian)', 'Population (Hispanic)', 'Median Age',
#        'Median Age (Male)', 'Median Age (Female)', 'Education (None)',
#        'Education (High School)', 'Education (GED)', 'Education (Associates)',
#        'Education (Bachelors)', 'Education (Masters)',
#        'Education (Professional)', 'Education (Doctorate)', 'Median Income',
#        'Income Per Capita', 'Median Home Value', 'Pop in Labor Force',
#        'Pop Not in Labor Force', 'Unemployed'],
#       dtype='object')

# %%
# Create scatterplot for Median Home Value vs. DEM %
plt.style.use('fivethirtyeight')
x_values = merged_df["Median Home Value"]
y_values = merged_df["DEM %"]
plt.title("Indiana, by County, Median Home Value for \n2016 DEM Presidential Vote %", fontsize=15, color="darkblue", weight="bold")
plt.ylabel("DEM %", fontsize=13, weight="bold")
plt.xlabel("Median Home Value", fontsize=13, weight="bold")

# Calculate & plot linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Format plot
plt.scatter(x_values,y_values,
            marker="d",
            facecolors="blue",
           edgecolors="blue",
            s=25,
            alpha=0.99)
plt.plot(x_values,regress_values,"seagreen")
plt.xticks(rotation='vertical')
plt.grid(linestyle="dotted")

# Set x-axis & y-axis limits
plt.xlim(50000, 250000);
plt.ylim(0, 1);

# Display & save
plt.plot(merged_df["Median Home Value"],regress_values,"black")
plt.annotate(rvalue, (190000,0.9), fontsize=14, color="gold")
plt.annotate(line_eq, (190000,0.8), fontsize=14, color="green")

print(f"The r-squared value is: {rvalue}")
print(line_eq)

plt.savefig("Median_Home_Value_vs_Dem.png")
plt.show()
# Out:
# The r-squared value is: 0.26133046594691894
# y = 0.0x + 0.18

# %%
# Create scatterplot for Median Home Value vs. GOP %
plt.style.use('fivethirtyeight')
x_values = merged_df["Median Home Value"]
y_values = merged_df["GOP %"]
plt.title("Indiana, by County, Median Home Value for \n2016 GOP Presidential Vote %", fontsize=15, color="crimson", weight="bold")
plt.ylabel("GOP %", fontsize=13, weight="bold")
plt.xlabel("Median Home Value", fontsize=13, weight="bold")

# Calculate & plot linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Format plot
plt.scatter(x_values,y_values,
            marker="d",
            facecolors="crimson",
           edgecolors="crimson",
            s=25,
            alpha=0.99)
plt.plot(x_values,regress_values,"seagreen")
plt.xticks(rotation='vertical')
plt.grid(linestyle="dotted")

# Set x-axis & y-axis limits
plt.xlim(50000, 250000);
plt.ylim(0, 1);

# Display & save
plt.plot(merged_df["Median Home Value"],regress_values,"black")
plt.annotate(rvalue, (190000,0.9), fontsize=14, color="gold")
plt.annotate(line_eq, (190000,0.8), fontsize=14, color="green")

print(f"The r-squared value is: {rvalue}")
print(line_eq)

marion=merged_df.loc[(merged_df["County"]=="Marion County")]
marion.head()
x_marion=marion["Median Home Value"][48]
y_marion=marion["GOP %"][48]
plt.annotate('Marion Co.',(x_marion,y_marion), fontsize=10)

plt.savefig("Median_Home_Value_vs_GOP.png")
plt.show()
# Out:
# The r-squared value is: -0.2771356920887946
# y = -0.0x + 0.78

# %%
# Create scatterplot for Median Home Value vs. DEM %
plt.style.use('fivethirtyeight')
x_values = merged_df["Median Home Value"]
y_values = merged_df["DEM %"]
plt.title("Indiana, by County, Median Home Value for \n2016 DEM Presidential Vote %", fontsize=15, color="darkblue", weight="bold")
plt.ylabel("DEM %", fontsize=13, weight="bold")
plt.xlabel("Median Home Value", fontsize=13, weight="bold")

# Calculate & plot linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Format plot
plt.scatter(x_values,y_values,
            marker="d",
            facecolors="blue",
           edgecolors="blue",
            s=25,
            alpha=0.99)
plt.plot(x_values,regress_values,"seagreen")
plt.xticks(rotation='vertical')
plt.grid(linestyle="dotted")

# Set x-axis & y-axis limits
plt.xlim(50000, 250000);
plt.ylim(0, 1);

# Display & save
plt.plot(merged_df["Median Home Value"],regress_values,"black")
plt.annotate(rvalue, (190000,0.9), fontsize=14, color="gold")
plt.annotate(line_eq, (190000,0.8), fontsize=14, color="green")

print(f"The r-squared value is: {rvalue}")
print(line_eq)

plt.savefig("Median_Home_Value_vs_Dem.png")
plt.show()

# Create scatterplot for Median Home Value vs. GOP %
plt.style.use('fivethirtyeight')
x_values = merged_df["Median Home Value"]
y_values = merged_df["GOP %"]
plt.title("Indiana, by County, Median Home Value for \n2016 GOP Presidential Vote %", fontsize=15, color="crimson", weight="bold")
plt.ylabel("GOP %", fontsize=13, weight="bold")
plt.xlabel("Median Home Value", fontsize=13, weight="bold")

# Calculate & plot linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Format plot
plt.scatter(x_values,y_values,
            marker="d",
            facecolors="crimson",
           edgecolors="crimson",
            s=25,
            alpha=0.99)
plt.plot(x_values,regress_values,"seagreen")
plt.xticks(rotation='vertical')
plt.grid(linestyle="dotted")

# Set x-axis & y-axis limits
plt.xlim(50000, 250000);
plt.ylim(0, 1);

# Display & save
plt.plot(merged_df["Median Home Value"],regress_values,"black")
plt.annotate(rvalue, (190000,0.9), fontsize=14, color="gold")
plt.annotate(line_eq, (190000,0.8), fontsize=14, color="green")

print(f"The r-squared value is: {rvalue}")
print(line_eq)

marion=merged_df.loc[(merged_df["County"]=="Marion County")]
marion.head()
x_marion=marion["Median Home Value"][48]
y_marion=marion["GOP %"][48]
plt.annotate('Marion Co.',(x_marion,y_marion), fontsize=10)

plt.savefig("Median_Home_Value_vs_GOP.png")
plt.show()
# Out:
# The r-squared value is: 0.26133046594691883
# y = 0.0x + 0.18
# The r-squared value is: -0.2771356920887946
# y = -0.0x + 0.78

# %%
# Generate bar plot - Median Home Value by County with DEM % and GOP %
merged_df = merged_df.sort_values('DEM %', axis=0, ascending=False)

med_home_value = merged_df[['County', 'DEM %', 'GOP %', 'Median Home Value']]
med_home_value.plot(x='Median Home Value', kind='bar', width=0.5, figsize=(30,10))


#merged_df.sort_values('DEM %', ascending=False) #[['a','b']].plot.bar(stacked=True)


#x_axis = 

# Formatting
plt.title("Median Home Value vs. GOP/DEM Vote %", fontsize=15)
plt.xlabel("County", fontsize = 13)
plt.ylabel("Vote Percentage", fontsize = 13)
#plt.xlim(0, 500000)
plt.ylim(0, 1)
plt.legend(fontsize = 10)

#plt.xticks(x_axis, regimens)
#tick_locations = [value for value in 'x_axis']
#plt.xticks(tick_locations, [["County"]], rotation='vertical')

plt.savefig("Median_Home_Value_vs_Dem&GOP Vote_SideBySide.png")
plt.show()
plt.tight_layout()

# %%
# Generate bar plot - Median Home Value by County with DEM % and GOP %
a = pd.Series(["DEM %"])
b = pd.Series(["GOP %"])
a_b = a+b

stacked_df = pd.concat([a,b,a_b],axis=1,join='inner')
stacked_df.columns = ['a','b','c']
df[['a','b']].sort_values(by='a',ascending=False).plot(kind='bar',stacked=True)

plt.tight_layout()
plt.show()


med_home_value = merged_df[['County', 'DEM %', 'GOP %', 'Median Home Value']]
med_home_value.plot(x='Median Home Value', kind='bar', width=0.5, figsize=(30,10))


#merged_df.sort_values('DEM %', ascending=False) #[['a','b']].plot.bar(stacked=True)


#x_axis = 

# Formatting
plt.title("Median Home Value vs. GOP/DEM Vote %", fontsize=15)
plt.xlabel("County", fontsize = 13)
plt.ylabel("Vote Percentage", fontsize = 13)
#plt.xlim(0, 500000)
plt.ylim(0, 1)
plt.legend(fontsize = 10)

#plt.xticks(x_axis, regimens)
#tick_locations = [value for value in 'x_axis']
#plt.xticks(tick_locations, [["County"]], rotation='vertical')

plt.show()
plt.tight_layout()
